# %% [markdown]
# ### Домашнее задание 3
#
# Используем предобработанные в рамках 1-ого домашнего задания датасет combine_df_prepocessed.pkl. Используем столбец 'clean_tweet'.
#
# ##### Задание 1.
# Используя библиотеку Spacy, вывести ТОП-20 популярных NER в combine_df датасете. Какой тип NER (ORG, GPE, PERSON и тд) оказался самым популярным?
# (Учтите, что max_word_limit_spacy для Spacy =  1000000)
#
# С помощью Spacy выяснить: какие персоны и организации самые обсуждаемые в train и test датасетах? вывести ТОП-20 самых популярных. Действительно ли в топ вошли только персоны и организации или есть мусор?
#
# Повторим шаги из заданий 1 и 2, используя библиотеку nltk.
# #####  Задание 2.
# Используя библиотеку nltk, вывести ТОП-20 популярных NER в combine_df датасете. Какой тип NER (ORG, GPE, PERSON и тд) оказался самым популярным?
# Для данного задания используем ограничение на количество символов во входном датасете (max_word_limit_spacy =  1000000), чтобы иметь возможность сравнить результаты работы  Spacy и nltk.
# Обратите внимание, что nltk чувствителен к регистру.
#
# С помощью nltk выяснить: какие персоны и организации самые обсуждаемые в train и test датасетах? вывести ТОП-20 самых популярных. Действительно ли в топ вошли только персоны и организации или есть мусор?
#
# ##### Задание 3.
# Какая из библиотек по вашему лучше отработала? Сравните качество полученных most_common NER и количество распознаных NER.

# %%
import pandas as pd
import collections
import re
import nltk

import spacy
#install spacy model
#!pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.2.0/en_core_web_md-2.2.0.tar.gz
import en_core_web_md

# %%
combine_df = pd.read_pickle('combine_df_prepocessed.pkl')
combine_df.head()
# Out:
#    id  label                                              tweet  \
# 0   1    0.0   @user when a father is dysfunctional and is s...
# 1   2    0.0  @user @user thanks for #lyft credit i can't us...
# 2   3    0.0                                bihday your majesty
# 3   4    0.0  #model   i love u take with u all the time in ...
# 4   5    0.0             factsguide: society now    #motivation
#
#                                          clean_tweet  \
# 0  when father is dysfunctional and is so selfish...
# 1  thanks for lyft credit cannot use cause they d...
# 2                                bihday your majesty
# 3  model love yoyou take with yoyou all the time ...
# 4                  factsguide society now motivation
#
#                                          tweet_token  \
# 0  [when, father, is, dysfunctional, and, is, so,...
# 1  [thanks, for, lyft, credit, can, not, use, cau...
# 2                            [bihday, your, majesty]
# 3  [model, love, yoyou, take, with, yoyou, all, t...
# 4             [factsguide, society, now, motivation]
#
#                                 tweet_token_filtered  \
# 0  [father, dysfunctional, selfish, drags, kids, ...
# 1  [thanks, lyft, credit, use, cause, offer, whee...
# 2                                  [bihday, majesty]
# 3    [model, love, yoyou, take, yoyou, time, yoyour]
# 4                  [factsguide, society, motivation]
#
#                                        tweet_stemmed  \
# 0      father dysfunct selfish drag kid dysfunct run
# 1  thank lyft credit use caus offer wheelchair va...
# 2                                     bihday majesti
# 3            model love yoyou take yoyou time yoyour
# 4                            factsguid societi motiv
#
#                                     tweet_lemmatized
# 0  father dysfunctional selfish drag kid dysfunct...
# 1  thanks lyft credit use cause offer wheelchair ...
# 2                                     bihday majesty
# 3            model love yoyou take yoyou time yoyour
# 4                      factsguide society motivation

# %% [markdown]
# ### Задание 1.
# Spacy tagger. Популярные NER, персоны, организации

# %%
 # Объединяем все слова в 1 список
def words_union(df):
    words_list = []
    for line in df['tweet']:
        line_words = line.split()
        words_list.extend(line_words)
    words = ' '.join(words_list)
    return words

# %%
words = words_union(combine_df)
max_word_limit_spacy = 1000000
nlp = en_core_web_md.load()
doc = nlp(words[:max_word_limit_spacy])
tokens_list = [(ent.text, ent.label_) for ent in doc.ents]
tokens_list
# Out:
# [('#', 'CARDINAL'),
#  ('lyft', 'PERSON'),
#  ('pdx', 'GPE'),
#  ('#disapointed #', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('ð\x9f\x92¦', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('2/2', 'CARDINAL'),
#  ('allshowandnogo', 'PERSON'),
#  ('tomorrow', 'DATE'),
#  ('the next school year', 'DATE'),
#  ('the year', 'DATE'),
#  ('ð\x9f\x98\xad #school #exams', 'ORG'),
#  ('allin', 'PERSON'),
#  ('cavs #', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('cleveland', 'GPE'),
#  ('clevelandcavaliers â\x80', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#ireland', 'GPE'),
#  ('previous 0.2% to 0.5%', 'PERCENT'),
#  ('may #', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('orlando', 'PERSON'),
#  ('standwithorlando', 'PERSON'),
#  ('pulseshooting', 'PERSON'),
#  ('orlandoshooting', 'PERSON'),
#  ('heabreaking', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('today', 'DATE'),
#  ('#80days', 'MONEY'),
#  ('gettingfed', 'ORG'),
#  ('cnn', 'ORG'),
#  ('#', 'CARDINAL'),
#  ("michigan middle school '", 'ORG'),
#  ('tcot', 'PERSON'),
#  ('#australia #', 'MONEY'),
#  ('thecove', 'PERSON'),
#  ('helpcovedolphins', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('omg', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#friday', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('euro2016', 'PERSON'),
#  ('rooney', 'PERSON'),
#  ('bale', 'PERSON'),
#  ('#badday #', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('the day', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('the #weekend', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('tgif', 'TIME'),
#  ('ff', 'ORG'),
#  ('80', 'CARDINAL'),
#  ('45.00', 'MONEY'),
#  ('upsideofflorida', 'PERSON'),
#  ('shopalyssas', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('ð\x9f\x98\x9cð\x9f\x98\x88', 'PERSON'),
#  ('pressconference', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('antalya', 'GPE'),
#  ('turkey', 'GPE'),
#  ('sunday #', 'DATE'),
#  ('50', 'CARDINAL'),
#  ('a good night', 'TIME'),
#  ('1', 'CARDINAL'),
#  ('rip#orlando', 'MONEY'),
#  ('alohafriday', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('positivevibes', 'PERSON'),
#  ('hawaiian', 'NORP'),
#  ('nohern ireland', 'GPE'),
#  ('sadley', 'ORG'),
#  ('tonight', 'TIME'),
#  ('gawa', 'PERSON'),
#  ('a hard monday', 'DATE'),
#  ('today', 'DATE'),
#  ('badmonday', 'PERSON'),
#  ('the 21st century', 'DATE'),
#  ('#neverump', 'MONEY'),
#  ('dalat', 'GPE'),
#  ('ripinkylife', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('photoshop', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('cedarpoint', 'PERSON'),
#  ('2 hours', 'TIME'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('knicks', 'ORG'),
#  ('nba', 'ORG'),
#  ('ð\x9f\x98\x8e', 'GPE'),
#  ('iphonesia #', 'ORG'),
#  ('blooms', 'PERSON'),
#  ('basilicabotanica', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('blue #', 'ORG'),
#  ('abc2020', 'PERSON'),
#  ('2', 'CARDINAL'),
#  ('frm #pulseclub', 'ORG'),
#  ('bihday', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('bihday', 'PERSON'),
#  ('concelebrate', 'ORG'),
#  ('first', 'ORDINAL'),
#  ('dolores', 'PERSON'),
#  ('capas tarlac', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('rayos', 'PERSON'),
#  ('rayos #', 'ORG'),
#  ('ascot times', 'ORG'),
#  ('â\x9d¤ï¸\x8fâ\x9d¤ï¸\x8f', 'PERSON'),
#  ('ascot', 'PERSON'),
#  ('#monochrome', 'MONEY'),
#  ('the weekend', 'DATE'),
#  ('like4like', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ("christina grimmie's", 'PERSON'),
#  ('#christinarip #voice #', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('roar #', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('poland', 'GPE'),
#  ('bridget &amp', 'ORG'),
#  ('chatiado', 'PERSON'),
#  ('ð\x9f\x91\x8fð\x9f\x8f½ð\x9f\x91\x8fð\x9f\x8f½ð\x9f\x91\x8fð\x9f\x8f½ hour',
#   'PRODUCT'),
#  ('morning', 'TIME'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#luv #', 'MONEY'),
#  ('aworks', 'PERSON'),
#  ('florida', 'GPE'),
#  ('orlando', 'GPE'),
#  ('#', 'CARDINAL'),
#  ('disneygatorattack', 'PERSON'),
#  ('two year old', 'DATE'),
#  ('ferrari', 'ORG'),
#  ('itð\x9f\x92ªð\x9f\x8f¼', 'ORG'),
#  ('gp', 'ORG'),
#  ('ferrari', 'ORG'),
#  ('ð\x9f\x98\x8d', 'ORG'),
#  ('first', 'ORDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('amarinder', 'PERSON'),
#  ('aap', 'PERSON'),
#  ('senseaboutmaths', 'PERSON'),
#  ('6th', 'ORDINAL'),
#  ('#', 'CARDINAL'),
#  ('#medâ\x80¦', 'MONEY'),
#  ('today', 'DATE'),
#  ('#golfstrengthandconditioning #', 'MONEY'),
#  ('felixfoisgolf', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('greathonour', 'PERSON'),
#  ('careerconvos', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#wateringhole #', 'MONEY'),
#  ('campfire', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#altwaystoheal #', 'MONEY'),
#  ('just over 5 weeks', 'DATE'),
#  ('hus', 'NORP'),
#  ('tonight', 'TIME'),
#  ('#midweek', 'MONEY'),
#  ('newmusic #', 'ORG'),
#  ('guitar', 'PERSON'),
#  ('monday nights', 'DATE'),
#  ('8pm', 'TIME'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('15', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('october', 'DATE'),
#  ('goodtimes', 'PERSON'),
#  ('ð\x9f\x8dº', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('urð\x9f\x93±', 'PERSON'),
#  ('japanese', 'NORP'),
#  ('edwardsville', 'GPE'),
#  ('pennsylvania', 'GPE'),
#  ('7.99', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#cool #', 'MONEY'),
#  ('obama', 'PERSON'),
#  ('orlando', 'ORG'),
#  ('8 years', 'DATE'),
#  ('nashvilletour2016', 'PERSON'),
#  ('#eur/usd', 'MONEY'),
#  ('1.1400', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('tomorrow', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('sta baking #', 'ORG'),
#  ('#vigilfororlando #', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('ihavenofriends', 'PERSON'),
#  ('someonecomewithme', 'PERSON'),
#  ('sunday', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('sunday', 'DATE'),
#  ('marilynmonroe', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('race &amp', 'ORG'),
#  ('about #', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('marvel', 'PERSON'),
#  ('#musica', 'MONEY'),
#  ('adele', 'GPE'),
#  ('obama', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('brexit', 'GPE'),
#  ('#silver #gold #', 'MONEY'),
#  ('100', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#ofw', 'MONEY'),
#  ('pinoy', 'GPE'),
#  ('instagood #smile #', 'ORG'),
#  ('# #', 'MONEY'),
#  ('#breakups #alone #', 'MONEY'),
#  ('50 laps', 'CARDINAL'),
#  ('10k', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('cotd', 'ORG'),
#  ('muslim', 'NORP'),
#  ('50', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('friday', 'DATE'),
#  ('ð\x9f\x98\x8eð\x9f\x98\x8eð\x9f\x98\x8eð\x9f\x8c\x9eð\x9f\x8c\x9eð\x9f\x8c\x9eó¾',
#   'ORG'),
#  ('usa', 'GPE'),
#  ('las vegas', 'GPE'),
#  ('ma fleurette', 'PERSON'),
#  ('smiles#blackandwhite', 'ORG'),
#  ('itâ\x80\x99s', 'ORG'),
#  ('just rainy day', 'DATE'),
#  ('#3lines', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('river rd #', 'FAC'),
#  ('afterpas', 'PERSON'),
#  ('japan', 'GPE'),
#  ('ï¼\x83madeinjapan', 'ORG'),
#  ('eos', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('cawaii #', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('republican', 'NORP'),
#  ('fuhered &amp;â\x80¦', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('1466047260.15', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('social #analytics', 'ORG'),
#  ('photooftheday #', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('doj', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('fbi', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('negligence.why', 'MONEY'),
#  ('21thbihday', 'MONEY'),
#  ('ð\x9f\x92\x93', 'ORG'),
#  ('pooh4u', 'ORG'),
#  ('bihday chris', 'PERSON'),
#  ('chrisevans', 'PERSON'),
#  ('more than 50', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('florida', 'GPE'),
#  ('#', 'CARDINAL'),
#  ('newalbum #indie #guitars', 'ORG'),
#  ('echobelly', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('tgif #', 'ORG'),
#  ('seo', 'GPE'),
#  ('#', 'CARDINAL'),
#  ('weekend', 'DATE'),
#  ('nzd', 'MONEY'),
#  ('0.7190 #', 'MONEY'),
#  ('weeks', 'DATE'),
#  ('#bithday27', 'MONEY'),
#  ('sa', 'ORG'),
#  ('ð\x9f\x92« #disneysmagickingdom #', 'ORG'),
#  ('disney', 'ORG'),
#  ('magickingdom #', 'ORG'),
#  ('disneyland #orlandoâ\x80¦', 'ORG'),
#  ("gr8 blain's", 'PERSON'),
#  ('ð\x9f\x98\xad @user &lt;3', 'ORG'),
#  ('voice &lt;3 &lt;3 &lt;3 &lt;3 17', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('effo', 'GPE'),
#  ('effo', 'ORG'),
#  ('theodore', 'PERSON'),
#  ('2', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('michelleobama', 'PERSON'),
#  ('newarkfestival', 'PERSON'),
#  ('our 3rd year', 'DATE'),
#  ('netflix', 'ORG'),
#  ('#mochithepug', 'MONEY'),
#  ('puglife', 'PERSON'),
#  ('butstillontime', 'PERSON'),
#  ('barry', 'PERSON'),
#  ('knicks', 'PERSON'),
#  ('#golfâ\x80', 'MONEY'),
#  ('friday', 'DATE'),
#  ('this weekend', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('goodmorning', 'PERSON'),
#  ('friday', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('florida', 'GPE'),
#  ('aap', 'PERSON'),
#  ('70%', 'PERCENT'),
#  ('punjabis', 'NORP'),
#  ('#', 'CARDINAL'),
#  ('drugaddicts', 'NORP'),
#  ('#', 'CARDINAL'),
#  ('tracerequest', 'ORG'),
#  ('orlando', 'GPE'),
#  ('zimbabwe', 'GPE'),
#  ('hea #', 'ORG'),
#  ('#guy', 'MONEY'),
#  ('saturday', 'DATE'),
#  ('afternoon', 'TIME'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('nut &amp', 'ORG'),
#  ('bing bong', 'PERSON'),
#  ('2 months', 'DATE'),
#  ('summer', 'DATE'),
#  ('35th', 'ORDINAL'),
#  ('bihday', 'PERSON'),
#  ('watson', 'PERSON'),
#  ('bihday', 'PERSON'),
#  ('watson #australia #', 'ORG'),
#  ('cricker', 'ORG'),
#  ('one', 'CARDINAL'),
#  ('millions', 'CARDINAL'),
#  ('jewishsupremacist', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('two', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('radio1', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('tonight', 'TIME'),
#  ('republicans', 'NORP'),
#  ('nra', 'ORG'),
#  ('#sad #', 'MONEY'),
#  ('#alone #', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#fine #', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('halffull #halfempty #mikeashley #', 'ORG'),
#  ('sposdirectshame', 'GPE'),
#  ('perhapse', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('workersrights', 'PERSON'),
#  ('europe', 'LOC'),
#  ('stella', 'PERSON'),
#  ('#birds', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('last night', 'TIME'),
#  ('one', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('orlando', 'PERSON'),
#  ('heabreaking', 'PERSON'),
#  ('margaret lee #runbeck', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#altwaystoheal', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#makingbeats #', 'MONEY'),
#  ('thursday', 'DATE'),
#  ('10', 'CARDINAL'),
#  ('the cipd ireland conference &amp', 'ORG'),
#  ('workshop #cpd', 'ORG'),
#  ('onemoreday', 'MONEY'),
#  ('200', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('hypu #stream', 'ORG'),
#  ('tomorrow', 'DATE'),
#  ('#verbal #', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('this last year', 'DATE'),
#  ('the stadium &amp', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#amoureuxâ\x80¦', 'MONEY'),
#  ('lawofattraction #', 'ORG'),
#  ('quiz', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#pole', 'MONEY'),
#  ('bgp #rozthediva #blackgirlspole', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('argentina2015', 'MONEY'),
#  ('nohcarolina', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('orlando', 'MONEY'),
#  ('photographerdubai', 'PERSON'),
#  ('montreal', 'GPE'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#wimbledon2016', 'PERSON'),
#  ('#ff', 'MONEY'),
#  ('#fashionâ\x80¦ #', 'MONEY'),
#  ('#day', 'MONEY'),
#  ('chinatown mall', 'FAC'),
#  ('binondo', 'GPE'),
#  ('â\x80', 'PERSON'),
#  ('america', 'GPE'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('magnettherapy', 'PERSON'),
#  ('sebbo', 'PERSON'),
#  ('egã\x80\x9cï¼\x9fï¼\x9fï¼\x9f smile!!!!!â\x9d¤ï¸\x8fð\x9f\x97£ð\x9f¤\x98ð\x9f\x8f½',
#   'PERSON'),
#  ('#smile#egsmile #', 'MONEY'),
#  ('kettering', 'GPE'),
#  ('today', 'DATE'),
#  ('potp', 'ORG'),
#  ('the way toraya #bus', 'ORG'),
#  ('white #', 'ORG'),
#  ('#carrieunderwood #', 'MONEY'),
#  ('6', 'CARDINAL'),
#  ('bridpo food &amp', 'ORG'),
#  ('5', 'MONEY'),
#  ('#propey #', 'MONEY'),
#  ('ocean #', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('pakistan', 'GPE'),
#  ('allin216', 'GPE'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('countdown', 'PERSON'),
#  ('nolefam', 'ORG'),
#  ('milan', 'GPE'),
#  ('22092016', 'MONEY'),
#  ('two', 'CARDINAL'),
#  ('wakow', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('298 days', 'DATE'),
#  ('lef b4', 'PERSON'),
#  ('classez', 'ORG'),
#  ('#risay18', 'MONEY'),
#  ('thursday', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('i_am', 'ORG'),
#  ('the united states of america', 'GPE'),
#  ('a good weekend', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('jeffreycwilliams', 'MONEY'),
#  ('hu #buttrue', 'PERSON'),
#  ('knownð\x9f\x92\x93 #cute #smiles #babygirl', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('#t.b.c ?', 'MONEY'),
#  ('oneteamlincoln', 'PERSON'),
#  ('carowinds', 'PERSON'),
#  ('#rockthepark #', 'MONEY'),
#  ('timetogetmyjesuson', 'PERSON'),
#  ('every minute', 'TIME'),
#  ('sixty seconds', 'TIME'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('sanjapan', 'PERSON'),
#  ('september', 'DATE'),
#  ('the day', 'DATE'),
#  ('tech #', 'ORG'),
#  ('today', 'DATE'),
#  ('mondaymotivation', 'PERSON'),
#  ('livelifetothefullest', 'GPE'),
#  ('#everydaycounts', 'PERCENT'),
#  ('anna #classmate #', 'ORG'),
#  ('#brentwood #', 'MONEY'),
#  ('#kitten #cat #', 'MONEY'),
#  ('ð\x9f\x87¿ð\x9f\x87¦', 'PERSON'),
#  ('themeowood', 'PERSON'),
#  ('puppy few more days', 'DATE'),
#  ('ð\x9f\x98\x8d', 'PERSON'),
#  ('pharrell williams #pharrellwilliams lyrics', 'ORG'),
#  ('#workâ\x80', 'MONEY'),
#  ('yesterday:-', 'PERSON'),
#  ('rosie yayyy', 'PERSON'),
#  ('2morrow #', 'DATE'),
#  ('#mad #', 'MONEY'),
#  ('#dog #', 'MONEY'),
#  ('dreamcatcher', 'PERSON'),
#  ('tomorrow', 'DATE'),
#  ('ecuador', 'GPE'),
#  ('#', 'CARDINAL'),
#  ('dallas', 'GPE'),
#  ('itako#alone#it', 'PERSON'),
#  ('sunshine &amp', 'ORG'),
#  ('saturday', 'DATE'),
#  ('ð\x9f\x91¸ð\x9f\x8f½', 'ORG'),
#  ('letthembelittle', 'PERSON'),
#  ('childhoodunplugged', 'ORG'),
#  ('today', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('chubbygirl', 'ORG'),
#  ('finnishgirl', 'PERSON'),
#  ('finn buka bersama tma', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('yuhuuuuu', 'PERSON'),
#  ('meylucky, &amp', 'ORG'),
#  ('3', 'CARDINAL'),
#  ('mayfair townhouse', 'FAC'),
#  ('ny', 'GPE'),
#  ('african-american', 'NORP'),
#  ('#â\x80¦ #', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('ð\x9f\x98\x94', 'PERSON'),
#  ('30', 'CARDINAL'),
#  ('#ugh', 'MONEY'),
#  ('ð\x9f\x92¦', 'PERSON'),
#  ('ð\x9f\x98\x98ð\x9f\x98\x98ð\x9f\x98\x98 #game', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('many#pols', 'ORG'),
#  ('#bluelivesmatter #', 'MONEY'),
#  ('draintheswamp', 'PERSON'),
#  ('ferguson sequoia', 'ORG'),
#  ('$', 'MONEY'),
#  ('the end of the week', 'DATE'),
#  ('bham', 'GPE'),
#  ('ofbham', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('positivevibes', 'PERSON'),
#  ('concord mills', 'FAC'),
#  ('conjuring2', 'MONEY'),
#  ('tonight', 'TIME'),
#  ('readyornot', 'PERSON'),
#  ('truestory', 'PERSON'),
#  ('the day', 'DATE'),
#  ('nabilah', 'PERSON'),
#  ('ð\x9f\x98\x8d arigatou', 'PERSON'),
#  ('iwearbanana', 'PERSON'),
#  ('last day', 'DATE'),
#  ('tomorrow', 'DATE'),
#  ('monday #', 'DATE'),
#  ('redditchbizhour', 'PERSON'),
#  ('half', 'CARDINAL'),
#  ('half', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('corbinrayp', 'PERSON'),
#  ('zero', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('missyou', 'PERSON'),
#  ('whatwasthat', 'GPE'),
#  ('monday', 'DATE'),
#  ('#mondaymorning', 'MONEY'),
#  ('monday', 'DATE'),
#  ('muzlin 5b', 'PRODUCT'),
#  ('#', 'CARDINAL'),
#  ('4 happy hour', 'TIME'),
#  ('toddlerfriends', 'PERSON'),
#  ('latergram', 'PERSON'),
#  ('toddlerfun', 'MONEY'),
#  ('orlando', 'PERSON'),
#  ('munich', 'GPE'),
#  ('pharrell', 'PERSON'),
#  ('netherlands', 'GPE'),
#  ('u hu', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('thankfulthursday', 'PERSON'),
#  ('i_am', 'ORG'),
#  ('a week tomorrow', 'DATE'),
#  ('bihday', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('bihday #', 'ORG'),
#  ('liverpool', 'GPE'),
#  ('athens', 'GPE'),
#  ('santorini', 'GPE'),
#  ('freakshake', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#yum #', 'MONEY'),
#  ('dalston', 'MONEY'),
#  ('saturdays', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('ð\x9f\x98³', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('#organic #', 'MONEY'),
#  ('#fruit', 'MONEY'),
#  ('#organic #', 'MONEY'),
#  ('first months', 'DATE'),
#  ('weeks', 'DATE'),
#  ('only days', 'DATE'),
#  ('the beginning of the end of @user i am both', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('blackpool', 'GPE'),
#  ('today', 'DATE'),
#  ('newblood16', 'MONEY'),
#  ('96', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('7', 'CARDINAL'),
#  ('2016', 'MONEY'),
#  ('robson-kanu', 'PERSON'),
#  ('s6', 'ORG'),
#  ('usa', 'GPE'),
#  ('2b proud of &amp', 'ORG'),
#  ('stephcurry', 'PERSON'),
#  ('christians', 'NORP'),
#  ('#', 'CARDINAL'),
#  ('8 more weeks', 'DATE'),
#  ('missyou', 'PERSON'),
#  ('mybrotherskeeper', 'MONEY'),
#  ('hocoschools', 'PERSON'),
#  ('columbiamd', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('sanya', 'PERSON'),
#  ('whererefreshingbegins', 'PERSON'),
#  ('lifeaftersurgery', 'PERSON'),
#  ('labradorretriever', 'PERSON'),
#  ('lifeofsam', 'GPE'),
#  ('superspoilt', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('nba', 'ORG'),
#  ('steph', 'PERSON'),
#  ('thompson', 'PERSON'),
#  ('kyrie', 'PERSON'),
#  ('lebron', 'PERSON'),
#  ('guillermo', 'PERSON'),
#  ('#mep #', 'MONEY'),
#  ('urð\x9f\x93±', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#food4thought', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('independence hall', 'FAC'),
#  ("kiss donald's", 'PERSON'),
#  ('#pathetic &amp', 'ORG'),
#  ('racism &amp', 'ORG'),
#  ('ripgop', 'PERSON'),
#  ('bing bong', 'PERSON'),
#  ('instapic', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('graffiti #', 'ORG'),
#  ('dublin', 'GPE'),
#  ('ireland', 'GPE'),
#  ('#', 'CARDINAL'),
#  ('vimeo #movie #video #europe', 'ORG'),
#  ('#rafalwojcicki #', 'MONEY'),
#  ('oitnbseason4', 'MONEY'),
#  ('2 days', 'DATE'),
#  ('today', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('extraordinaryladyspeaks', 'PERSON'),
#  ('starawards', 'PERSON'),
#  ('thursday', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('sunnyday #', 'ORG'),
#  ('#blueâ\x80¦', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('neshl', 'MONEY'),
#  ('2016', 'DATE'),
#  ('#bhl #', 'MONEY'),
#  ('sunday', 'DATE'),
#  ('tonyawards', 'PERSON'),
#  ('2016', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#rock', 'MONEY'),
#  ('#beatles #', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('the week, june 13, 2016', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#300dayshappy', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#love#lifequotes #', 'MONEY'),
#  ('blaze', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#july4th #fireworks â\x80', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('today', 'DATE'),
#  ('#thevoice', 'MONEY'),
#  ('#stopthehate #', 'MONEY'),
#  ('like 90%', 'PERCENT'),
#  ('today', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('lawofattraction #', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('#altwaystoheal #', 'MONEY'),
#  ('idwp', 'PERSON'),
#  ('trump ny co-', 'ORG'),
#  ('michelle obama', 'PERSON'),
#  ('#p2 #p21', 'MONEY'),
#  ('tcot', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#altwaystoheal #', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('a million', 'CARDINAL'),
#  ('craig', 'PERSON'),
#  ('shane lowry', 'PERSON'),
#  ('hour', 'TIME'),
#  ('2-4-1', 'CARDINAL'),
#  ('4-7pm', 'TIME'),
#  ('42', 'CARDINAL'),
#  ('buffalo anas + nimra + farishta + mawia + khushal 960 + 952 + 503 + 484 + 435 =',
#   'ORG'),
#  ('3334', 'CARDINAL'),
#  ('monday', 'DATE'),
#  ('#thebachelorette #', 'MONEY'),
#  ('nowine suppoing', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('topoli', 'PERSON'),
#  ('vaitacacommafiasdv', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('torrington', 'GPE'),
#  ('#instadaily #', 'MONEY'),
#  ('withmom', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('sunset #ride #bikes', 'ORG'),
#  ('#fitness', 'ORG'),
#  ('#deseâ\x80', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('tagsforlikes #me', 'ORG'),
#  ('#food#friends#summer#swag#quotes', 'MONEY'),
#  ('polaroid #', 'ORG'),
#  ('11:11', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('pointscore', 'ORG'),
#  ('wednesdaywisdom', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#beautiful #smooth #', 'MONEY'),
#  ('f4f #', 'ORG'),
#  ('#healing #', 'MONEY'),
#  ('loa', 'GPE'),
#  ('#healthy #', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('50.40', 'MONEY'),
#  ('eia', 'ORG'),
#  ('fuher', 'ORG'),
#  ('#newblood', 'MONEY'),
#  ('bihday', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#dog', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('bihdaygirl', 'ORG'),
#  ('5,000', 'CARDINAL'),
#  ('saskatchewan barn', 'GPE'),
#  ('americans', 'NORP'),
#  ('guncontrol', 'PERSON'),
#  ('today', 'DATE'),
#  ('baba siddique ifftar', 'PERSON'),
#  ('mumbai', 'GPE'),
#  ('@user &amp', 'ORG'),
#  ('dono ayenge', 'PERSON'),
#  ('#ombre', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('warcraft', 'ORG'),
#  ('warcraft', 'ORG'),
#  ('family#fun@user', 'MONEY'),
#  ("duane henry '", 'PERSON'),
#  ('&gt;&gt;&gt', 'ORG'),
#  ('#lover #', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('blacklivesmatter &amp', 'ORG'),
#  ('june 16', 'DATE'),
#  ('#summev #zoo', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#altwaystoheal #', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('bihdaycelebrations', 'PERSON'),
#  ('william james', 'PERSON'),
#  ('xtra', 'PERSON'),
#  ('sunday', 'DATE'),
#  ('today', 'DATE'),
#  ('a good day :)', 'DATE'),
#  ('sunday', 'DATE'),
#  ('masterkeyexperience', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#ilovemysisterâ\x80¦', 'MONEY'),
#  ('tomorrow', 'DATE'),
#  ('ð\x9f\x98\x8d', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('2016', 'DATE'),
#  ('bbc', 'ORG'),
#  ('france', 'GPE'),
#  ('#euros sta', 'MONEY'),
#  ('today', 'DATE'),
#  ('many years', 'DATE'),
#  ('tiggy ð\x9f\x98¢', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('jax &amp', 'ORG'),
#  ('ð\x9f\x98\x88 #soa #', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('eurogamer', 'MONEY'),
#  ('this year', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('eurogamer2016', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('tapfoags', 'PERSON'),
#  ('â\x80', 'PERSON'),
#  ('nazis', 'NORP'),
#  ('american', 'NORP'),
#  ('ushistory', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('sun #', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('picnic #', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('river island', 'LOC'),
#  ('#retailtherapy #', 'MONEY'),
#  ('zoing ziy', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('laundryday', 'MONEY'),
#  ('2', 'CARDINAL'),
#  ('ebay', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('night', 'TIME'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('altright', 'NORP'),
#  ('african', 'NORP'),
#  ('potus', 'PERSON'),
#  ('theresistance', 'PERSON'),
#  ('°', 'CARDINAL'),
#  ('ð\x9f\x8d', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('idola #', 'ORG'),
#  ('followme', 'PERSON'),
#  ('selfie', 'ORG'),
#  ('america', 'GPE'),
#  ('first', 'ORDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('orlando #america', 'ORG'),
#  ('today', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('brexit', 'PERSON'),
#  ('germany', 'GPE'),
#  ('japan', 'GPE'),
#  ('bbh #blog #', 'ORG'),
#  ('#â\x80¦', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('alohabeachbus', 'PERSON'),
#  ('hawaii', 'GPE'),
#  ('years', 'DATE'),
#  ('tacloban', 'GPE'),
#  ('tacloban city', 'GPE'),
#  ('catbalogan', 'GPE'),
#  ('olympics', 'EVENT'),
#  ('2016', 'DATE'),
#  ('#birds #', 'MONEY'),
#  ('#il #', 'MONEY'),
#  ('sunday', 'DATE'),
#  ('#', 'CARDINAL'),
#  ('#model', 'MONEY'),
#  ('urbex #topless #tits #mono #retweet', 'ORG'),
#  ('# #', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('saturday', 'DATE'),
#  ('today', 'DATE'),
#  ('shegotmarried â\x80', 'PERSON'),
#  ('urð\x9f\x93±', 'PERSON'),
#  ('lewis', 'PERSON'),
#  ('chris', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#spring #', 'MONEY'),
#  ('wales', 'GPE'),
#  ('#sun', 'MONEY'),
#  ('euros2016', 'PERSON'),
#  ('#like4likeâ\x80¦', 'MONEY'),
#  ('2', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('kpop', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('notborderlands', 'PERSON'),
#  ('goblizzard', 'PERSON'),
#  ('an hour', 'TIME'),
#  ('fatkidinacandystore', 'PERSON'),
#  ('c2c', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#snapchat #', 'MONEY'),
#  ('#', 'CARDINAL'),
#  (':/', 'CARDINAL'),
#  ('apaments', 'PERSON'),
#  ('#', 'CARDINAL'),
#  ('#altwaystoheal', 'MONEY'),
#  ('msgapparelstoday', 'PERSON'),
#  ('us', 'GPE'),
#  ('next weekend', 'DATE'),
#  ('#lovecamping', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('#nofilter #', 'MONEY'),
#  ('instagood â\x80', 'PERSON'),
#  ('carlos', 'PERSON'),
#  ('5th', 'ORDINAL'),
#  ('#318', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('thealter', 'PERSON'),
#  ('us', 'GPE'),
#  ('0.2%', 'PERCENT'),
#  ('danske bank #blog #', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('fathersday #', 'ORG'),
#  ('coolestlifehack', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('uk', 'GPE'),
#  ('mp', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('#truestory', 'PERSON'),
#  ('brithday day', 'DATE'),
#  ('#monday', 'MONEY'),
#  ('ukrainians', 'NORP'),
#  ('grosseto', 'GPE'),
#  ('oitnb stas', 'PERSON'),
#  ('tonight', 'TIME'),
#  ('#oitnbseason4', 'MONEY'),
#  ('tonight', 'TIME'),
#  ('out!!!ð\x9f\x98©ð\x9f\x98«ð\x9f\x98', 'ORG'),
#  ('noooo', 'ORG'),
#  ('jordans', 'MONEY'),
#  ('#', 'CARDINAL'),
#  ('#', 'CARDINAL'),
#  ('i_am', 'ORG'),
#  ('#', 'CARDINAL'),
#  ('27th', 'ORDINAL'),
#  ('nyc #newyorkcity', 'ORG'),
#  ...]

# %%
# TOP-20 популярных NER
collections.Counter(tokens_list).most_common(20)
# Out:
# [(('#', 'CARDINAL'), 7785),
#  (('today', 'DATE'), 385),
#  (('tomorrow', 'DATE'), 151),
#  (('one', 'CARDINAL'), 141),
#  (('first', 'ORDINAL'), 137),
#  (('friday', 'DATE'), 122),
#  (('2', 'CARDINAL'), 113),
#  (('tonight', 'TIME'), 103),
#  (('bihday', 'PERSON'), 99),
#  (('sunday', 'DATE'), 97),
#  (('saturday', 'DATE'), 77),
#  (('urð\x9f\x93±', 'PERSON'), 60),
#  (('i_am', 'ORG'), 58),
#  (('â\x80¦', 'PERSON'), 56),
#  (('#altwaystoheal #', 'MONEY'), 55),
#  (('summer', 'DATE'), 55),
#  (('4', 'CARDINAL'), 53),
#  (('morning', 'TIME'), 49),
#  (('monday', 'DATE'), 49),
#  (('â\x80', 'PERSON'), 48)]

# %%
# TOP-20 популярных личностей
person_tokens_list = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ == 'PERSON']
collections.Counter(person_tokens_list).most_common(20)
# Out:
# [(('bihday', 'PERSON'), 99),
#  (('urð\x9f\x93±', 'PERSON'), 60),
#  (('â\x80¦', 'PERSON'), 56),
#  (('â\x80', 'PERSON'), 48),
#  (('fathersday', 'PERSON'), 44),
#  (('euro2016', 'PERSON'), 33),
#  (('obama', 'PERSON'), 29),
#  (('allahsoil', 'PERSON'), 25),
#  (('tbt', 'PERSON'), 25),
#  (('bing bong', 'PERSON'), 24),
#  (('orlandoshooting', 'PERSON'), 23),
#  (('ð\x9f\x98¢', 'PERSON'), 20),
#  (('selfie', 'PERSON'), 17),
#  (('orlando', 'PERSON'), 16),
#  (('brexit', 'PERSON'), 13),
#  (('hillary', 'PERSON'), 13),
#  (('cantwait', 'PERSON'), 12),
#  (('lighttherapy', 'PERSON'), 12),
#  (('god', 'PERSON'), 12),
#  (('ripchristina', 'PERSON'), 12)]

# %%
# TOP-20 популярных организаций
org_tokens_list = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ == 'ORG']
collections.Counter(org_tokens_list).most_common(20)
# Out:
# [(('i_am', 'ORG'), 58),
#  (('&amp', 'ORG'), 20),
#  (('@user &amp', 'ORG'), 17),
#  (('nba', 'ORG'), 16),
#  (('blur #', 'ORG'), 16),
#  (('ð\x9f\x8d', 'ORG'), 14),
#  (('â\x80', 'ORG'), 14),
#  (('gop', 'ORG'), 13),
#  (('disney', 'ORG'), 12),
#  (('netflix', 'ORG'), 12),
#  (('black &amp', 'ORG'), 12),
#  (('ð\x9f\x98\x94', 'ORG'), 12),
#  (('orlando', 'ORG'), 11),
#  (('social #analytics', 'ORG'), 9),
#  (('bihdaygirl', 'ORG'), 9),
#  (('â\x80¦', 'ORG'), 9),
#  (('&gt;&gt;&gt', 'ORG'), 8),
#  (('goodmorning #', 'ORG'), 8),
#  (('f4f', 'ORG'), 8),
#  (('bihday', 'ORG'), 8)]

# %%
# сколько уникальных NER найдено с помощью spacy?
len(collections.Counter(tokens_list))
# Out:
# 10740

# %% [markdown]
# ### Задание 2.
# NLTK tagger. Популярные NER, персоны, организации

# %%
words = words_union(combine_df)
max_word_limit_spacy = 1000000
tokens_list = [(' '.join(c[0] for c in chunk), chunk.label() ) for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(words[:max_word_limit_spacy]))) if hasattr(chunk, 'label') ]

# %%
tokens_list
# Out:
# [('en-ger-land', 'GPE'),
#  ('u.s.', 'GPE'),
#  ('nycÂ', 'ORGANIZATION'),
#  ('travelÂ', 'ORGANIZATION'),
#  ('mr. velicaria', 'PERSON'),
#  ('atÂ', 'ORGANIZATION'),
#  ('u.s.', 'GPE'),
#  ('whiteaddictÂ', 'ORGANIZATION'),
#  ('inc.', 'ORGANIZATION'),
#  ('u.s.', 'GPE'),
#  ('leastâ\x80¦', 'ORGANIZATION'),
#  ('perÃº', 'ORGANIZATION'),
#  ('sÃ³ria', 'ORGANIZATION'),
#  ('____________________________________', 'ORGANIZATION'),
#  ('firstÂ', 'ORGANIZATION'),
#  ('moanaÂ', 'ORGANIZATION'),
#  ('ludik.hugo', 'ORGANIZATION'),
#  ('isrâ\x80¦', 'GPE'),
#  ('littleÂ', 'ORGANIZATION'),
#  ('u.s.', 'GPE')]

# %%
# TOP-20 популярных NER
collections.Counter(tokens_list).most_common(20)
# Out:
# [(('User', 'PERSON'), 172),
#  (('Ur', 'GPE'), 136),
#  (('Will', 'PERSON'), 86),
#  (('New', 'GPE'), 67),
#  (('User', 'GPE'), 44),
#  (('Us', 'GPE'), 43),
#  (('Delete Old', 'PERSON'), 42),
#  (('Happy', 'PERSON'), 32),
#  (('Forward', 'PERSON'), 32),
#  (('Cold', 'GPE'), 31),
#  (('Libtard', 'PERSON'), 31),
#  (('Father', 'PERSON'), 30),
#  (('User User', 'PERSON'), 29),
#  (('Orlando', 'GPE'), 26),
#  (('User', 'ORGANIZATION'), 26),
#  (('Grateful', 'PERSON'), 25),
#  (('Vicinity Of Their', 'ORGANIZATION'), 23),
#  (('Being', 'GPE'), 22),
#  (('Sad', 'PERSON'), 21),
#  (('Fathers', 'ORGANIZATION'), 21)]

# %%
# TOP-20 популярных личностей
person_tokens_list = [(ent[0], ent[1]) for ent in tokens_list if ent[1] == 'PERSON']
collections.Counter(person_tokens_list).most_common(20)
# Out:
# [(('User', 'PERSON'), 172),
#  (('Will', 'PERSON'), 86),
#  (('Delete Old', 'PERSON'), 42),
#  (('Happy', 'PERSON'), 32),
#  (('Forward', 'PERSON'), 32),
#  (('Libtard', 'PERSON'), 31),
#  (('Father', 'PERSON'), 30),
#  (('User User', 'PERSON'), 29),
#  (('Grateful', 'PERSON'), 25),
#  (('Sad', 'PERSON'), 21),
#  (('Hard', 'PERSON'), 18),
#  (('Been', 'PERSON'), 18),
#  (('Gorilla Simulator', 'PERSON'), 18),
#  (('Model Love Take', 'PERSON'), 18),
#  (('Strong Source', 'PERSON'), 16),
#  (('Climb Racing Angry Polar Bear Climb', 'PERSON'), 15),
#  (('Good', 'PERSON'), 14),
#  (('Gon', 'PERSON'), 14),
#  (('Him', 'PERSON'), 13),
#  (('Hill Climb', 'PERSON'), 13)]

# %%
# TOP-20 популярных организаций
org_tokens_list = [(ent[0], ent[1]) for ent in tokens_list if ent[1] == 'ORGANIZATION']
collections.Counter(org_tokens_list).most_common(20)
# Out:
# [(('User', 'ORGANIZATION'), 26),
#  (('Vicinity Of Their', 'ORGANIZATION'), 23),
#  (('Fathers', 'ORGANIZATION'), 21),
#  (('Lot', 'ORGANIZATION'), 20),
#  (('Vast Expanse Of Mountains', 'ORGANIZATION'), 17),
#  (('All', 'ORGANIZATION'), 16),
#  (('Work Conference', 'ORGANIZATION'), 15),
#  (('House', 'ORGANIZATION'), 14),
#  (('Well Deletetweets', 'ORGANIZATION'), 11),
#  (('Best', 'ORGANIZATION'), 11),
#  (('Weekend', 'ORGANIZATION'), 10),
#  (('No', 'ORGANIZATION'), 10),
#  (('Same', 'ORGANIZATION'), 10),
#  (('Into', 'ORGANIZATION'), 10),
#  (('Work', 'ORGANIZATION'), 8),
#  (('Most', 'ORGANIZATION'), 8),
#  (('Happiness', 'ORGANIZATION'), 8),
#  (('Tell', 'ORGANIZATION'), 8),
#  (('Are', 'ORGANIZATION'), 8),
#  (('Orlando', 'ORGANIZATION'), 7)]

# %%
# сколько уникальных NER найдено с помощью spacy?
len(collections.Counter(tokens_list))

# %% [markdown]
# ### Задание 3.
# Какая из библиотек по вашему лучше отработала? Сравните качество полученных most_common NER и количество распознаных NER.

# %% [markdown]
# в Nltk очень много шума из-за заглавных букв, качественнее результат дала библиотека Spacy.
